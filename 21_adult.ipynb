# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DSBDALExamDataSets/Adult/adult.csv')

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.rename(columns={'50K<= >50K':'salary'},inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df['sex'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
df['sex'].replace(' Male','1',inplace=True)
df['sex'].replace(' Female','0',inplace=True)
df['salary'].replace(' <=50K','0',inplace=True)
df['salary'].replace(' >50K','1',inplace=True)

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race sex  \
# 0            Never-married        Adm-clerical   Not-in-family   White   1
# ...

# %%
data = df['age']
plt.hist(data)
plt.xlabel('age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data = df['hours-per-week'].iloc[0:50]
pos=[]
keys={}
i=0
for num in data:
    if num not in keys:
        keys[num]=1
        pos.append(1)
    else:
        keys[num]+=1
        pos.append(keys[num])
plt.scatter(data,pos)
plt.show()
#sns.stripplot(df['hours-per-week'])

# %%
x=df['salary'].value_counts()

data=x.values
label=['<50K','>50K']
plt.bar(label,data)
# Out:
# <BarContainer object of 2 artists>

# %%
x=df['hours-per-week'].iloc[:100]
y=df['salary']
sns.scatterplot(x)
# Out:
# <Axes: ylabel='hours-per-week'>

# %%
data1=df['age'].iloc[:100]
data2=df['hours-per-week'].iloc[:100]
plt.plot(data1,data2)

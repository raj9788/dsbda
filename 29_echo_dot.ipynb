# %%
import bs4
import requests

# %%
link="https://www.flipkart.com/google-nest-mini-2nd-gen-assistant-smart-speaker/p/itma20dcd67c740a?pid=ATNFM44TKMMUSAJK&lid=LSTATNFM44TKMMUSAJKWQ8CJU&marketplace=FLIPKART&q=google+assistant&store=0pm%2F0o7&srno=s_1_5&otracker=AS_QueryStore_OrganicAutoSuggest_1_9_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_9_na_na_ps&fm=search-autosuggest&iid=899ded77-7006-4134-b124-6f890ea7ff87.ATNFM44TKMMUSAJK.SEARCH&ppt=sp&ppn=sp&ssid=793ltte7cg0000001685211187495&qH=a0b03034b66c636c"
page = requests.get(link)
page
# Out:
# <Response [200]>

# %%
html = bs4.BeautifulSoup(page.content,'html.parser')
html
soup = bs4.BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# reviews = soup.findAll('div',{'class':'t-ZTKy'})
# for r in reviews:
#     print(r.get_text()+'\n')

# %%
ratings = soup.findAll('div',{'class':'_3LWZlK _1BLPMq'})
for r in ratings:
    print(r.get_text()+'\n')
# Out:
# 5
#
# 4
#
# 5
#
# 5
#
# 4
#
# 4
#
# 5
#
# 5

# %%
names = soup.findAll('p',{'class':'_2sc7ZR _2V5EHH'})
for name in names:
    print(name.get_text()+'\n')
# Out:
# Aji G
#
# Sunil kumar
#
# Sachin Yadav
#
# Sk Md Salman
#
# Soumyajit Maity
#
# Sanuj Bhatnagar
#
# Muskan Vazirani
#
# Praveen Rockz
#
# Rahul Kumar
#
# PSK MUDALIAR

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df['name'] = names[:5]

# %%
df['Rating']=ratings[:5]

# %%
df
# Out:
#                 name   Rating
# 0            [Aji G]  [5, []]
# 1      [Sunil kumar]  [4, []]
# 2     [Sachin Yadav]  [5, []]
# 3     [Sk Md Salman]  [5, []]
# 4  [Soumyajit Maity]  [4, []]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DSBDALExamDataSets\dataset_Facebook.csv',delimiter=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
photo_subset = df.loc[df['Type']=='Photo']

# %%
photo_subset
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
video_subset = df.loc[df['Type']=='Video']

# %%
video_subset
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
merged_set = pd.merge(left=video_subset,right
                      =photo_subset,how='outer')

# %%
merged_set
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              138895  Video         1          12             4         11
# 1              138329  Video         1          11             6          2
# 2              137893  Video         1          11             5          3
# 3              137893  Video         1          11             3         11
# 4              134879  Video         1           9             2         10
# ..                ...    ...       ...         ...           ...        ...
# 428             85093  Photo         3           1             7          2
# 429             81370  Photo         2           1             5          8
# 430             81370  Photo         1           1             5          2
# 431             81370  Photo         3           1             4         11
# 432             81370  Photo         2           1             4          4
#
# ...

# %%
sorted_data_on_likes = df.sort_values('like',ascending=False)

# %%
sorted_data_on_likes
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
transpose_data = df.transpose()

# %%
transpose_data
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
melt_data = pd.melt(df)

# %%
melt_data.head(10)
# Out:
#            variable   value
# 0  Page total likes  139441
# 1  Page total likes  139441
# 2  Page total likes  139441
# 3  Page total likes  139441
# 4  Page total likes  139441
# 5  Page total likes  139441
# 6  Page total likes  139441
# 7  Page total likes  139441
# 8  Page total likes  139441
# 9  Page total likes  139441

# %%
wide_df = df.pivot_table(index=['Type','Category','like','share','comment']).reset_index()

# %%
wide_df
# Out:
#       Type  Category   like  share  comment  Lifetime Engaged Users  \
# 0     Link         1    5.0    2.0        0                    66.0
# 1     Link         1    6.0    0.0        0                    24.0
# 2     Link         1   12.0    1.0        1                    84.0
# 3     Link         1   12.0    2.0        0                    66.0
# 4     Link         1   16.0    2.0        0                   118.0
# ..     ...       ...    ...    ...      ...                     ...
# 481  Video         1  143.0   13.0       18                  1141.0
# 482  Video         1  204.0   44.0       23                  1779.0
# 483  Video         1  315.0   76.0       18                  3872.0
# 484  Video         1  345.0  121.0        6                  2080.0
# 485  Video         1  449.0   84.0       17                  2101.0
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                 59.0
# ...

# %%
wide_df.shape
# Out:
# (486, 19)

# %%
import pandas as pd
import numpy as np

# %%
credits = pd.read_csv('DSBDALExamDataSets/Movie/credits.csv')
keywords = pd.read_csv('DSBDALExamDataSets/Movie/keywords.csv')
links = pd.read_csv('DSBDALExamDataSets/Movie/links_small.csv')
movie_data = pd.read_csv('DSBDALExamDataSets/Movie/movies_metadata.csv')
rating = pd.read_csv('DSBDALExamDataSets/Movie/ratings_small.csv')
# Out:
# C:\Users\rajma\AppData\Local\Temp\ipykernel_26032\4169425335.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_data = pd.read_csv('DSBDALExamDataSets/Movie/movies_metadata.csv')

# %%
movie_data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
movie_data.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
movie_data = movie_data.dropna(axis=1)

# %%
movie_data.isna().sum()
movie_data.dtypes
# Out:
# adult              object
# budget             object
# genres             object
# id                float64
# original_title     object
# dtype: object

# %%
# for col in df.columns:
#     if col!='num':
#         df[col] = pd.to_numeric(df[col], errors='coerce')
#         df[col] = df[col].fillna(df[col].median).astype(int)
movie_data['id']=pd.to_numeric(movie_data['id'], errors='coerce')
# Out:
# C:\Users\rajma\AppData\Local\Temp\ipykernel_26032\3420169357.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data['id']=pd.to_numeric(movie_data['id'], errors='coerce')

# %%
rating.dtypes
rating.astype('float').dtypes
rating.rename(columns={'movieId':'id'},inplace=True)

# %%
merge_set = pd.merge(movie_data,rating,how='inner',on='id')

# %%
merge_set
# Out:
#        adult    budget                                             genres  \
# 0      False  60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 1      False  60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2      False  60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 3      False  60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4      False  60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...      ...       ...                                                ...
# 44989  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 44990  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 44991  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 44992  False         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 44993  False         0  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
#
#             id                        original_title  userId  rating  \
# ...

# %%
melt_set = merge_set.melt()

# %%
melt_set
# Out:
#          variable       value
# 0           adult       False
# 1           adult       False
# 2           adult       False
# 3           adult       False
# 4           adult       False
# ...           ...         ...
# 359947  timestamp  1441513491
# 359948  timestamp  1435789819
# 359949  timestamp  1241951834
# 359950  timestamp  1420521986
# 359951  timestamp  1228072108
#
# [359952 rows x 2 columns]

# %%
cast_set = merge_set.pivot_table(columns=['id','original_title','rating']).reset_index()
# Out:
# C:\Users\rajma\AppData\Local\Temp\ipykernel_26032\2920506565.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   cast_set = merge_set.pivot_table(columns=['id','original_title','rating']).reset_index()

# %%
cast_set
# Out:
# id                  index           2.0                              \
# original_title                    Ariel
# rating                              1.5           2.0           2.5
# 0               timestamp  1.228946e+09  1.070607e+09  1.291082e+09
# 1                  userId  5.000000e+02  2.919167e+02  1.868333e+02
#
# id                                                                      \
# original_title
# rating                   3.0           3.5           4.0           4.5
# 0               1.035572e+09  1.259133e+09  9.878782e+08  1.361246e+09
# 1               3.585676e+02  1.725000e+02  3.847407e+02  1.340000e+02
#
# id                                            3.0  ...      134881.0  \
# original_title               Varjoja paratiisissa  ...    More of Me
# rating                   5.0                  0.5  ...           4.0
# 0               1.050242e+09         1.112384e+09  ...  1.462295e+09
# 1               2.680769e+02         4.250000e+02  ...  5.855000e+02
# ...

# %%
cast_set.transpose()
# Out:
#                                                      0           1
# id       original_title      rating
# index                                        timestamp      userId
# 2.0      Ariel               1.5          1228946281.0       500.0
#                              2.0     1070607084.666667  291.916667
#                              2.5          1291081733.0  186.833333
#                              3.0     1035571961.594595  358.567568
# ...                                                ...         ...
# 142507.0 Exit                3.0          1465793179.0        15.0
# 148652.0 The Eleventh Victim 2.5          1462946405.0       402.0
# 158238.0 Stolen Seas         3.5          1465794051.0        15.0
#                              4.0          1470719796.0        73.0
# 160718.0 I Spy Returns       4.0          1469713151.0       547.0
#
# [10352 rows x 2 columns]

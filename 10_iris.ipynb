# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DSBDALExamDataSets/Iris/Iris.csv')

# %%
df
# Out:
#      sepal length in cm   sepal width in cm  petal length in cm  \
# 0                   5.1                 3.5                 1.4
# 1                   4.9                 3.0                 1.4
# 2                   4.7                 3.2                 1.3
# 3                   4.6                 3.1                 1.5
# 4                   5.0                 3.6                 1.4
# ..                  ...                 ...                 ...
# 145                 6.7                 3.0                 5.2
# 146                 6.3                 2.5                 5.0
# 147                 6.5                 3.0                 5.2
# 148                 6.2                 3.4                 5.4
# 149                 5.9                 3.0                 5.1
#
#       petal width in cm           class
# 0                   0.2     Iris-setosa
# 1                   0.2     Iris-setosa
# 2                   0.2     Iris-setosa
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal length in cm  150 non-null    float64
#  1    sepal width in cm  150 non-null    float64
#  2   petal length in cm  150 non-null    float64
#  3    petal width in cm  150 non-null    float64
#  4   class               150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal length in cm   sepal width in cm  petal length in cm  \
# count          150.000000          150.000000          150.000000
# mean             5.843333            3.054000            3.758667
# std              0.828066            0.433594            1.764420
# min              4.300000            2.000000            1.000000
# 25%              5.100000            2.800000            1.600000
# 50%              5.800000            3.000000            4.350000
# 75%              6.400000            3.300000            5.100000
# max              7.900000            4.400000            6.900000
#
#         petal width in cm
# count          150.000000
# mean             1.198667
# std              0.763161
# min              0.100000
# 25%              0.300000
# 50%              1.300000
# 75%              1.800000
# max              2.500000

# %%
df.head()
# Out:
#    sepal length in cm   sepal width in cm  petal length in cm  \
# 0                 5.1                 3.5                 1.4
# 1                 4.9                 3.0                 1.4
# 2                 4.7                 3.2                 1.3
# 3                 4.6                 3.1                 1.5
# 4                 5.0                 3.6                 1.4
#
#     petal width in cm        class
# 0                 0.2  Iris-setosa
# 1                 0.2  Iris-setosa
# 2                 0.2  Iris-setosa
# 3                 0.2  Iris-setosa
# 4                 0.2  Iris-setosa

# %%
print(df['class'].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
Iris_setosa = df[df['class']=='Iris-setosa']

# %%
Iris_setosa
# Out:
#     sepal length in cm   sepal width in cm  petal length in cm  \
# 0                  5.1                 3.5                 1.4
# 1                  4.9                 3.0                 1.4
# 2                  4.7                 3.2                 1.3
# 3                  4.6                 3.1                 1.5
# 4                  5.0                 3.6                 1.4
# 5                  5.4                 3.9                 1.7
# 6                  4.6                 3.4                 1.4
# 7                  5.0                 3.4                 1.5
# 8                  4.4                 2.9                 1.4
# 9                  4.9                 3.1                 1.5
# 10                 5.4                 3.7                 1.5
# 11                 4.8                 3.4                 1.6
# 12                 4.8                 3.0                 1.4
# 13                 4.3                 3.0                 1.1
# ...

# %%
Iris_versicolor = df[df['class']=='Iris-versicolor']
Iris_versicolor
# Out:
#     sepal length in cm   sepal width in cm  petal length in cm  \
# 50                 7.0                 3.2                 4.7
# 51                 6.4                 3.2                 4.5
# 52                 6.9                 3.1                 4.9
# 53                 5.5                 2.3                 4.0
# 54                 6.5                 2.8                 4.6
# 55                 5.7                 2.8                 4.5
# 56                 6.3                 3.3                 4.7
# 57                 4.9                 2.4                 3.3
# 58                 6.6                 2.9                 4.6
# 59                 5.2                 2.7                 3.9
# 60                 5.0                 2.0                 3.5
# 61                 5.9                 3.0                 4.2
# 62                 6.0                 2.2                 4.0
# 63                 6.1                 2.9                 4.7
# ...

# %%
Iris_virginica = df[df['class']=='Iris-virginica']
Iris_virginica
# Out:
#      sepal length in cm   sepal width in cm  petal length in cm  \
# 100                 6.3                 3.3                 6.0
# 101                 5.8                 2.7                 5.1
# 102                 7.1                 3.0                 5.9
# 103                 6.3                 2.9                 5.6
# 104                 6.5                 3.0                 5.8
# 105                 7.6                 3.0                 6.6
# 106                 4.9                 2.5                 4.5
# 107                 7.3                 2.9                 6.3
# 108                 6.7                 2.5                 5.8
# 109                 7.2                 3.6                 6.1
# 110                 6.5                 3.2                 5.1
# 111                 6.4                 2.7                 5.3
# 112                 6.8                 3.0                 5.5
# 113                 5.7                 2.5                 5.0
# ...

# %%
merge_set = pd.merge(left=Iris_setosa,right=
                     Iris_versicolor,how='outer')

# %%
merge_set.shape
# Out:
# (100, 5)

# %%
merge_set = pd.merge(left=merge_set,right=Iris_virginica,how='outer')

# %%
merge_set.shape
# Out:
# (150, 5)

# %%
sort_set = df.sort_values(by='petal length in cm',ascending = False)

# %%
sort_set
# Out:
#      sepal length in cm   sepal width in cm  petal length in cm  \
# 118                 7.7                 2.6                 6.9
# 122                 7.7                 2.8                 6.7
# 117                 7.7                 3.8                 6.7
# 105                 7.6                 3.0                 6.6
# 131                 7.9                 3.8                 6.4
# ..                  ...                 ...                 ...
# 36                  5.5                 3.5                 1.3
# 35                  5.0                 3.2                 1.2
# 14                  5.8                 4.0                 1.2
# 13                  4.3                 3.0                 1.1
# 22                  4.6                 3.6                 1.0
#
#       petal width in cm           class
# 118                 2.3  Iris-virginica
# 122                 2.0  Iris-virginica
# 117                 2.2  Iris-virginica
# ...

# %%
transpose_set = df.transpose

# %%
transpose_set
# Out:
# <bound method DataFrame.transpose of      sepal length in cm   sepal width in cm  petal length in cm  \
# 0                   5.1                 3.5                 1.4
# 1                   4.9                 3.0                 1.4
# 2                   4.7                 3.2                 1.3
# 3                   4.6                 3.1                 1.5
# 4                   5.0                 3.6                 1.4
# ..                  ...                 ...                 ...
# 145                 6.7                 3.0                 5.2
# 146                 6.3                 2.5                 5.0
# 147                 6.5                 3.0                 5.2
# 148                 6.2                 3.4                 5.4
# 149                 5.9                 3.0                 5.1
#
#       petal width in cm           class
# 0                   0.2     Iris-setosa
# 1                   0.2     Iris-setosa
# ...

# %%
melt_set= df.melt()

# %%
melt_set
# Out:
#                variable           value
# 0    sepal length in cm             5.1
# 1    sepal length in cm             4.9
# 2    sepal length in cm             4.7
# 3    sepal length in cm             4.6
# 4    sepal length in cm             5.0
# ..                  ...             ...
# 745               class  Iris-virginica
# 746               class  Iris-virginica
# 747               class  Iris-virginica
# 748               class  Iris-virginica
# 749               class  Iris-virginica
#
# [750 rows x 2 columns]

# %%
cast_set = df.pivot_table(index=['class','petal length in cm','sepal length in cm']).reset_index()

# %%
cast_set
# Out:
#               class  petal length in cm  sepal length in cm  \
# 0       Iris-setosa                 1.0                 4.6
# 1       Iris-setosa                 1.1                 4.3
# 2       Iris-setosa                 1.2                 5.0
# 3       Iris-setosa                 1.2                 5.8
# 4       Iris-setosa                 1.3                 4.4
# ..              ...                 ...                 ...
# 119  Iris-virginica                 6.3                 7.3
# 120  Iris-virginica                 6.4                 7.9
# 121  Iris-virginica                 6.6                 7.6
# 122  Iris-virginica                 6.7                 7.7
# 123  Iris-virginica                 6.9                 7.7
#
#       petal width in cm   sepal width in cm
# 0                   0.2                 3.6
# 1                   0.1                 3.0
# 2                   0.2                 3.2
# 3                   0.2                 4.0
# ...

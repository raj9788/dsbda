# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DSBDALExamDataSets/Adult/adult.csv')
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
male_set = df[df['sex']==' Male']
female_set = df[df['sex']==' Female']

# %%
male_set
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32557   40            Private  154374        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...

# %%
female_set
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 4       28        Private  338409      Bachelors             13
# 5       37        Private  284582        Masters             14
# 6       49        Private  160187            9th              5
# 8       31        Private   45781        Masters             14
# 12      23        Private  122272      Bachelors             13
# ...    ...            ...     ...            ...            ...
# 32546   37        Private  198216     Assoc-acdm             12
# 32549   43      State-gov  255835   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32558   58        Private  151910        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#                marital-status        occupation     relationship    race  \
# 4          Married-civ-spouse    Prof-specialty             Wife   Black
# ...

# %%
merge_set= pd.merge(left=male_set,right=female_set,how='outer')

# %%
merge_set
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       52   Self-emp-not-inc  209642        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32556   37            Private  198216     Assoc-acdm             12
# 32557   43          State-gov  255835   Some-college             10
# 32558   27            Private  257302     Assoc-acdm             12
# 32559   58            Private  151910        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation     relationship    race  \
# 0            Never-married        Adm-clerical    Not-in-family   White
# ...

# %%
sort_set=df.sort_values(by='hours-per-week',ascending=False)

# %%
sort_set
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 8654    30            Private  103596      HS-grad              9
# 15460   37            Private  241174    Bachelors             13
# 935     37            Private  176900      HS-grad              9
# 26250   36   Self-emp-not-inc  257250    Assoc-voc             11
# 16992   19            Private  121074      7th-8th              4
# ...    ...                ...     ...          ...            ...
# 22960   21            Private  184135      HS-grad              9
# 9147    75                  ?  260543         10th              6
# 29752   69                  ?  117525   Assoc-acdm             12
# 5590    78                  ?  363134      HS-grad              9
# 32525   81                  ?  120478    Assoc-voc             11
#
#             marital-status          occupation     relationship  \
# 8654         Never-married     Protective-serv    Not-in-family
# ...

# %%
transpose_set = df.transpose()

# %%
transpose_set
# Out:
#                           0                    1                   2      \
# age                          39                   50                  38
# workclass             State-gov     Self-emp-not-inc             Private
# fnlwgt                    77516                83311              215646
# education             Bachelors            Bachelors             HS-grad
# education-num                13                   13                   9
# marital-status    Never-married   Married-civ-spouse            Divorced
# occupation         Adm-clerical      Exec-managerial   Handlers-cleaners
# relationship      Not-in-family              Husband       Not-in-family
# race                      White                White               White
# sex                        Male                 Male                Male
# capital-gain               2174                    0                   0
# capital-loss                  0                    0                   0
# ...

# %%
melt_set = df.melt()

# %%
melt_set
# Out:
#           variable   value
# 0              age      39
# 1              age      50
# 2              age      38
# 3              age      53
# 4              age      28
# ...            ...     ...
# 488410  50K<= >50K   <=50K
# 488411  50K<= >50K    >50K
# 488412  50K<= >50K   <=50K
# 488413  50K<= >50K   <=50K
# 488414  50K<= >50K    >50K
#
# [488415 rows x 2 columns]

# %%
cast_set = df.pivot_table(index=['age','workclass']).reset_index()
# Out:
# C:\Users\rajma\AppData\Local\Temp\ipykernel_30472\2861166535.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   cast_set = df.pivot_table(index=['age','workclass']).reset_index()

# %%
cast_set
# Out:
#      age          workclass  capital-gain  capital-loss  education-num  \
# 0     17                  ?    549.218750      0.000000       6.593750
# 1     17        Federal-gov      0.000000   1602.000000       7.000000
# 2     17          Local-gov      0.000000    114.428571       6.642857
# 3     17       Never-worked      0.000000      0.000000       6.000000
# 4     17            Private     27.260000     44.293333       6.680000
# ..   ...                ...           ...           ...            ...
# 476   90                  ?    198.857143    622.285714       8.000000
# 477   90        Federal-gov      0.000000      0.000000       9.000000
# 478   90          Local-gov   7367.750000      0.000000       9.750000
# 479   90            Private   1386.535714     78.785714      10.321429
# 480   90   Self-emp-not-inc   4510.000000      0.000000      10.666667
#
#             fnlwgt  hours-per-week
# 0    208757.968750       26.625000
# 1     99893.000000       40.000000
# ...
